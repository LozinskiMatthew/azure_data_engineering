# %%
print("Hello world")
# Out:
# Hello world

# %%
import os
target = os.path.join(os.getcwd(), "data")

# %%
print(target)
# Out:
# /home/matthew/Desktop/azure_data_engineering/brazilian-ecommerce
